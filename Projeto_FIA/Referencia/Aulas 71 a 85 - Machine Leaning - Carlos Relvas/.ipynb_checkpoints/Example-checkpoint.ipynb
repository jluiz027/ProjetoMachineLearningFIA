# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing.imputation import Imputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.cross_validation import StratifiedKFold
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Read CSV's

# %%
import os

to_drop = ["job_name", "reason"]

# have to upload train by hand since for some reason it is nont available here
df_train = pd.read_csv("train_data.csv").set_index("ids").drop(to_drop, axis=1)
df_train = df_train[~df_train.default.isnull()]
df_train["default"] = df_train["default"].astype("int")
df_test = pd.read_csv("teste_data.csv").set_index("ids").drop(to_drop, axis=1)
print((df_train.shape, df_test.shape))
# Out:
# ((47952, 24), (12014, 23))

# %% [markdown]
# ## Missings, type and uniques

# %%
encode_cols = df_train.dtypes
encode_cols = encode_cols[encode_cols == object].index.tolist()

# stats
print(pd.concat([df_train.isnull().mean(), df_train.dtypes, df_train.T.apply(lambda x: x.nunique(), axis=1)], axis=1))
# Out:
#                            0        1      2
# default             0.000000    int64      2
# score_1             0.000000   object      7
# score_2             0.000000   object     35
# score_3             0.000000  float64     87
# score_4             0.000000  float64  47952
# score_5             0.000000  float64  47952
# score_6             0.000000  float64  47952
# risk_rate           0.000000  float64     79
# amount_borrowed     0.000000  float64  41588
# borrowed_in_months  0.000000  float64      2
# credit_limit        0.312813  float64  21804
# income              0.000000  float64  44196
# sign                0.316546   object     12
# gender              0.049570   object      2
# facebook_profile    0.099954   object      2
# state               0.000000   object     50
# zip                 0.000000   object    823
# channel             0.000000   object      1
# real_state          0.000000   object      5
# ok_since            0.586044  float64    101
# n_bankruptcies      0.003441  float64      7
# n_defaulted_loans   0.000313  float64      5
# n_accounts          0.000000  float64     45
# n_issues            0.259301  float64     45

# %% [markdown]
# ## Count Encoder

# %%
def get_encoder(df, col):
    dft = df[col].astype(str).to_frame().copy()
    dft["count"] = 1
    return dft.groupby(col).count().to_dict()["count"]
    
def encode_all(df_train, df_test, cols):
    for col in cols:
        enc = get_encoder(df_train, col)
        df_train[col] = df_train[col].astype(str).apply(lambda x: enc.get(x, -1))
        df_test[col] = df_test[col].astype(str).apply(lambda x: enc.get(x, -1))
    return df_train, df_test

# %%
df_train, df_test = encode_all(df_train, df_test, encode_cols)
df_train, df_test = df_train.fillna(-1), df_test.fillna(-1)
df_train.head()
# Out:
#                                       default  score_1  score_2  score_3  \
# ids
# c017198e-1d86-04e5-4639-5883c12f34af        0     6829     1221    300.0
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa        0     6829     1546    280.0
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894        0    16338     4008    420.0
# 63b5db01-9c03-28e9-a968-fc2709533e3f        0    16338     2610    400.0
# e89fd51d-796b-a12e-92ba-de710f5a10e0        0     1240      376    390.0
#
#                                          score_4   score_5     score_6  \
# ids
# c017198e-1d86-04e5-4639-5883c12f34af   98.943966  0.666203   84.552862
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa   98.801402  0.158028  111.156002
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894  107.506083  0.952076   93.556293
# 63b5db01-9c03-28e9-a968-fc2709533e3f  104.015198  0.269695   98.517418
# e89fd51d-796b-a12e-92ba-de710f5a10e0   99.872055  0.753891   95.456606
#
#                                       risk_rate  amount_borrowed  \
# ids
# c017198e-1d86-04e5-4639-5883c12f34af       0.57          5269.87
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa       0.44         35021.99
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894       0.37         20027.94
# 63b5db01-9c03-28e9-a968-fc2709533e3f       0.31          7216.22
# e89fd51d-796b-a12e-92ba-de710f5a10e0       0.51         16019.44
#
#                                       borrowed_in_months    ...     \
# ids                                                         ...
# c017198e-1d86-04e5-4639-5883c12f34af                60.0    ...
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa                36.0    ...
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894                60.0    ...
# 63b5db01-9c03-28e9-a968-fc2709533e3f                36.0    ...
# e89fd51d-796b-a12e-92ba-de710f5a10e0                60.0    ...
#
#                                       facebook_profile  state  zip  channel  \
# ids
# c017198e-1d86-04e5-4639-5883c12f34af             27252    418   75    47952
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa             27252   3633  398    47952
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894             27252    543   61    47952
# 63b5db01-9c03-28e9-a968-fc2709533e3f             15907   1913  427    47952
# e89fd51d-796b-a12e-92ba-de710f5a10e0             27252    153   37    47952
#
#                                       real_state  ok_since  n_bankruptcies  \
# ids
# c017198e-1d86-04e5-4639-5883c12f34af       23674      70.0             0.0
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa       23674      45.0             0.0
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894       23674      34.0             0.0
# 63b5db01-9c03-28e9-a968-fc2709533e3f       20284      64.0             1.0
# e89fd51d-796b-a12e-92ba-de710f5a10e0       20284      -1.0             0.0
#
#                                       n_defaulted_loans  n_accounts  n_issues
# ids
# c017198e-1d86-04e5-4639-5883c12f34af                0.0        10.0      -1.0
# ebd7fb8a-9413-4c09-e387-2781cb1a04aa                0.0        11.0      11.0
# 4192b843-bb6b-3e8d-c0fc-791ca9b69894                0.0        14.0      14.0
# 63b5db01-9c03-28e9-a968-fc2709533e3f                0.0         4.0       4.0
# e89fd51d-796b-a12e-92ba-de710f5a10e0                0.0        11.0      11.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=7, random_state=42, max_features=10, oob_score=True)

X_train, y_train = df_train.drop("default", axis=1), df_train["default"]
X_test = df_test

# %%
skf = StratifiedKFold(y_train, 3, shuffle=True, random_state=42)

# %% [markdown]
# ## Cross Validation

# %%
aucs = []
for (fold, (i_train, i_test)) in enumerate(skf):
    clf.fit(X_train.iloc[i_train], y_train.iloc[i_train])
    i_pred_proba = clf.predict_proba(X_train.iloc[i_test])
    print(i_pred_proba.shape)
    auc = roc_auc_score(y_train.iloc[i_test], i_pred_proba[:, 1])
    aucs.append(auc)
    print("AUC score on fold %i: %2.3f" % (fold, auc))
print("AUC: %2.3f +- %2.4f" % (np.mean(aucs), np.std(aucs)))
# Out:
# (15985, 2)
# AUC score on fold 0: 0.755
# (15984, 2)
# AUC score on fold 1: 0.754
# (15983, 2)
# AUC score on fold 2: 0.761
# AUC: 0.757 +- 0.0033

# %% [markdown]
# ## Final Fit

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features=10, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# ## Predict and save submission file

# %%
sub = pd.DataFrame(clf.predict_proba(X_test)[:, 1], columns=["prob"], index=X_test.index)
sub.to_csv("submission101.csv")
sub
# Out:
#                                           prob
# ids
# 5e78f987-3e90-55a9-12f8-423c4d63d254  0.083568
# f4f28e96-099f-0ffa-6956-d5befffb7191  0.192798
# b93c6a30-ce80-546c-7ee6-6fc7d27320b4  0.114423
# 54f1cfe1-8239-ba99-e926-61dba5a4b119  0.117629
# 5be46214-a131-1b23-673f-43aa906fa5d6  0.505498
# ed7197c9-d440-9688-7c50-e7ee4538b8db  0.105907
# 6e4fbdcb-1cc7-0d53-f86a-c6523866431b  0.244716
# f1818b94-3fd7-bce1-d227-06ca2b9c932d  0.060245
# 3238dad5-c7d4-060e-868d-f8de4770a1e8  0.093243
# d83383b5-a481-2e3a-49d7-fcf1027a257d  0.116262
# ebc98f7f-7447-5803-09e2-d16cb1596118  0.058616
# 5bc24ef6-74b7-5b85-6bea-af702ba57d77  0.342325
# a78d1531-2b51-4ceb-868f-ffdba2f82bd7  0.115439
# 19743101-eb13-b218-dbd6-f2b4a0fe450a  0.081962
# 569ff73a-03ff-f11a-6f97-0d46257d693f  0.054950
# 09afff51-573e-1bae-ccb3-4df9dd4c0eda  0.257414
# 0c8be807-8ae0-124b-78da-c467f8c0ffa9  0.189333
# f7bd7125-8642-970d-f6b8-f3f0f5cdb3ec  0.189778
# 33457ec0-de19-2032-6d31-4ef8f83c02c0  0.283945
# bf51a1df-1f87-1dab-cec3-1edbfce4e842  0.082550
# 1ff06ff8-bc39-3d3a-97ba-ac3546bac12b  0.098985
# 6830737f-5cee-ed88-ed3c-8b683fa49334  0.092218
# 40f6bc4a-4c0f-3210-374e-83b10ce5375b  0.130903
# 32cb0024-27f5-fd68-f70b-22b1ca89247e  0.123684
# 22d0749f-beba-2752-2326-22110f988914  0.316557
# e6df0de7-ccb2-326d-65de-f29e85edb207  0.195835
# 8682ab92-9772-0729-3c52-310c63f7cdc9  0.049235
# 401f1c91-fef5-3e21-0c4a-ceefd93b2f6f  0.041196
# a7130b88-d152-6e6b-6158-24516421dc85  0.123061
# a1fb48fb-8416-08d8-1f04-e0c4a335aea3  0.274199
# ...                                        ...
# 749c3574-3e15-52cc-6813-30a29c980b56  0.090234
# dde3ab40-ad5c-cf28-7ffb-47a03e06ab3b  0.103734
# 055eebb6-6fbb-5a9a-fd31-9fda2cab3819  0.046774
# e7630acb-6c20-b614-9159-0a015f672b93  0.079675
# 768b68f4-1f10-18e4-5fac-f497db5a3f36  0.048088
# ae2c72ef-3186-6289-71ad-0d6c93d8ab2e  0.060482
# dd8c4500-02de-7bfc-056d-d0eaed3769d1  0.217357
# f764b31d-6a83-d091-df67-9633f74be54b  0.083546
# f956c046-eeda-3257-baa3-0486bf3672f5  0.202884
# cb55f1a9-d5d9-2e9c-6e50-1b3b5b60c6de  0.264791
# 53ceb1cb-08be-c799-db48-b6b672e0fc16  0.080218
# 378b026e-99bd-25c8-bf2b-16a54a6daa1e  0.057503
# f49642af-c92a-6b34-a612-3de314ea90e9  0.106929
# dd3245e2-d293-a078-6bd6-6d5acd107bb1  0.034620
# a8669586-d43c-67c7-e1fd-8079cc525d30  0.045741
# a12bc915-6757-1756-6e7a-a4865fc52453  0.089353
# a86252d0-5a96-832e-4be7-a595681b4e62  0.192350
# a7339169-699e-58dc-b566-1644dfb2f850  0.105995
# 9c514bd7-9879-2f8a-c2bb-330884d763b8  0.595930
# c62e961f-430a-fa31-4270-964cb1fe24d3  0.301438
# eee60435-edbc-353c-0f49-5a5f1cfb21f2  0.112960
# 876b2fc9-ed9a-dca0-0b9e-6f7a66df8ce6  0.536858
# e690e53f-5b85-c4cb-8f14-380e9f79b9c3  0.354301
# e6c211c3-a877-de63-5770-0d186ab8bda7  0.080447
# 8bc8ea0f-35cb-31a3-b4a6-fa3e83ec8e3c  0.123954
# 17756739-e087-10fb-a86a-e8d349146686  0.223478
# 4a65802b-016d-6773-1e66-24ff98d2f2c2  0.096559
# 5ddbadfa-bef2-e21b-88f5-dd3c577aed65  0.076465
# a52f53bc-8a48-1443-0893-901a1cbebd00  0.139772
# 20db9b84-0482-d7ce-4e31-6672fdf0ecc3  0.152612
#
# [12014 rows x 1 columns]
